# %%
import sys
sys.path.append("/home/lenovo/projects/python_fundamental/LKP_PKB/aima_python")

from search import *

# =========================
# KASUS 1
# =========================
teyvat_map_1 = UndirectedGraph(dict(
    MondstadtCity=dict(Windrise=12, Springvale=15),
    Windrise=dict(DawnWinery=10),
    Springvale=dict(DawnWinery=8),
    DawnWinery=dict(StoneGate=30),
    StoneGate=dict(DihuaMarsh=25),
    DihuaMarsh=dict(WangshuInn=10, QingceVillage=20),
    WangshuInn=dict(LiyueHarbor=35),
    LiyueHarbor=dict(MtTianheng=12),
    MtTianheng=dict(QingceVillage=30)
))

problem1 = GraphProblem('MondstadtCity', 'QingceVillage', teyvat_map_1)

bfs1 = breadth_first_graph_search(problem1)
dfs1 = depth_first_graph_search(problem1)
ucs1 = uniform_cost_search(problem1)

print("=== KASUS 1 ===")
print("BFS path :", bfs1.solution())
print("DFS path :", dfs1.solution())
print("UCS path :", ucs1.solution())
print("UCS cost :", ucs1.path_cost)


# =========================
# KASUS 2
# =========================
teyvat_map_2 = UndirectedGraph(dict(
    KipumakiCliff=dict(CliffwatchCamp=5, StarsandShoal=4),
    CliffwatchCamp=dict(BarrowmossBarrens=7),
    BarrowmossBarrens=dict(DreadshadeMire=6),
    StarsandShoal=dict(BlueAmberLake=3),
    BlueAmberLake=dict(VoidseaOutlook=8),
    DreadshadeMire=dict(VoidseaOutlook=5),
    VoidseaOutlook=dict(WingOfKeres=6),
    WingOfKeres=dict(NashaTown=4)
))

problem2 = GraphProblem('KipumakiCliff', 'NashaTown', teyvat_map_2)

bfs2 = breadth_first_graph_search(problem2)
dfs2 = depth_first_graph_search(problem2)
ucs2 = uniform_cost_search(problem2)

print("\n=== KASUS 2 ===")
print("BFS path :", bfs2.solution())
print("DFS path :", dfs2.solution())
print("UCS path :", ucs2.solution())
print("UCS cost :", ucs2.path_cost)
# Out:
# === KASUS 1 ===
# BFS path : ['Windrise', 'DawnWinery', 'StoneGate', 'DihuaMarsh', 'QingceVillage']
# DFS path : ['Springvale', 'DawnWinery', 'StoneGate', 'DihuaMarsh', 'QingceVillage']
# UCS path : ['Windrise', 'DawnWinery', 'StoneGate', 'DihuaMarsh', 'QingceVillage']
# UCS cost : 97
#
# === KASUS 2 ===
# BFS path : ['StarsandShoal', 'BlueAmberLake', 'VoidseaOutlook', 'WingOfKeres', 'NashaTown']
# DFS path : ['StarsandShoal', 'BlueAmberLake', 'VoidseaOutlook', 'WingOfKeres', 'NashaTown']
# UCS path : ['StarsandShoal', 'BlueAmberLake', 'VoidseaOutlook', 'WingOfKeres', 'NashaTown']
# UCS cost : 25
